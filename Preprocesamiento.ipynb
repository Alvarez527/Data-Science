# %% [markdown]
# **Ciencia y analítica de datos**
#
# Carlos Álvarez
#
# Preprocesamiento de datos (Data Preprocessing)
#
# ---

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
DIR = "/content/drive/MyDrive/Colab Notebooks/MNA_TEC_DE_MONTERREY/Ciencia y Analitica de Datos_TC4029.11/Modulo 3/Actividad 5.0"
os.chdir(DIR)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
response_df = pd.read_csv('responses.csv')
response_df
# Out:
#       Music  Slow songs or fast songs  Dance  Folk  Country  Classical music  \
# 0       5.0                       3.0    2.0   1.0      2.0              2.0
# 1       4.0                       4.0    2.0   1.0      1.0              1.0
# 2       5.0                       5.0    2.0   2.0      3.0              4.0
# 3       5.0                       3.0    2.0   1.0      1.0              1.0
# 4       5.0                       3.0    4.0   3.0      2.0              4.0
# ...     ...                       ...    ...   ...      ...              ...
# 1005    5.0                       2.0    5.0   2.0      2.0              5.0
# 1006    4.0                       4.0    5.0   1.0      3.0              4.0
# 1007    4.0                       3.0    1.0   1.0      2.0              2.0
# 1008    5.0                       3.0    3.0   3.0      1.0              3.0
# 1009    5.0                       5.0    4.0   3.0      2.0              3.0
#
# ...

# %% [markdown]
# 1. Determina cuántas variables numéricas y cuántas de texto posee el conjunto de datos con el método `info()` y utiliza el método `describe()` del dataframe, para obtener el resumen de las estadísticas descriptivas. Separa el análisis según el tipo de datos (number, object).

# %%
#Existen 139 variables numéricas y 11 variables de texto
response_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1010 entries, 0 to 1009
# Columns: 150 entries, Music to House - block of flats
# dtypes: float64(134), int64(5), object(11)
# memory usage: 1.2+ MB

# %%
#Estadísticas descriptivas de valores numéricos:
response_df.describe().T
# Out:
#                              count        mean        std   min    25%    50%  \
# Music                       1007.0    4.731877   0.664049   1.0    5.0    5.0
# Slow songs or fast songs    1008.0    3.328373   0.833931   1.0    3.0    3.0
# Dance                       1006.0    3.113320   1.170568   1.0    2.0    3.0
# Folk                        1005.0    2.288557   1.138916   1.0    1.0    2.0
# Country                     1005.0    2.123383   1.076136   1.0    1.0    2.0
# ...                            ...         ...        ...   ...    ...    ...
# Spending on healthy eating  1008.0    3.557540   1.093750   1.0    3.0    4.0
# Age                         1003.0   20.433699   2.828840  15.0   19.0   20.0
# Height                       990.0  173.514141  10.024505  62.0  167.0  173.0
# Weight                       990.0   66.405051  13.839561  41.0   55.0   64.0
# Number of siblings          1004.0    1.297809   1.013348   0.0    1.0    1.0
#
# ...

# %%
#Etadísticas descriptivas con valores de texto.
response_df.describe(include = 'object').T
# Out:
#                        count unique                  top freq
# Smoking                 1002      4        tried smoking  430
# Alcohol                 1005      3       social drinker  659
# Punctuality             1008      3  i am always on time  399
# Lying                   1008      4            sometimes  549
# Internet usage          1010      4      few hours a day  744
# Gender                  1004      2               female  593
# Left - right handed     1007      2         right handed  906
# Education               1009      6     secondary school  621
# Only child              1008      2                   no  754
# Village - town          1006      2                 city  707
# House - block of flats  1006      2       block of flats  595

# %% [markdown]
# 2. Clasifique la variable `Weight` según su escala de medición. En función de ello elija el gráfico a generar (histograma / barras) y fundamente su elección.

# %%
#La variable Weight es una variable cuantitativa continua por lo que el análisis visual de los datos corresponde a un histograma.
#En un histograma se categoriza una variable numérica continua en terminos de bins los cuáles representarán la frecuencia de los datos en el histograma.

fig = plt.figure(figsize=(15,10))
ax= fig.add_subplot(1,1,1)
sns.histplot(response_df['Weight'], ax = ax, bins = 50, stat = 'density', color = 'deepskyblue', edgecolor= 'black')
sns.kdeplot(response_df['Weight'], color='red', ax = ax)
# Out:
# <Axes: xlabel='Weight', ylabel='Density'>

# %% [markdown]
# 3. Clasifique la distribución del peso según su asimetría, justificando tu respuesta. Incluye el cálculo numérico que lo demuestra.

# %%
#La asimetria es positiva puesto que el valor de "Skew"es mayor a uno, esto significa que la concentración de los datos esta a la izquierda.
response_df['Weight'].skew()
# Out:
# 1.2237251927527477

# %% [markdown]
# 4. ¿Cuántos valores faltantes tiene la variable `Weight`? ¿Qué porcentaje representa?

# %%
#Existen 20 valores faltantes para la variable "Weight" estos valores representan el 1.9% de todos los datos
valores_faltantes = response_df['Weight'].isna().sum()
valores_faltantes
(response_df['Weight'].isna().sum()/response_df.shape[0])*100
# Out:
# 1.9801980198019802

# %% [markdown]
# 5. ¿Tendrán los valores faltantes de `Weight` relación con alguna otra variable? Analízalo considerando las siguientes columnas:
# *   Numéricas: `Age, Number of siblings`
# *   Categóricas: `Gender, Education`
#
# Para ello deberás dividir cada columna en dos grupos: con/sin faltantes en `Weight` y utilizar métodos gráficos y la prueba t para ver si hay diferencias significativas. NO olvides incluir las conclusiones del análisis con los resultados obtenidos.
#
# **NOTA**. Puedes reutilizar las funciones `Diagnose_MV_Numerical` y `Diagnose_MV_Categorical` definidas en Hands-On-Prep_Missing_Values.zip. Revisa nuevamente cómo utilizarlas.

# %%
from scipy.stats import ttest_ind
def Diagnose_MV_Numerical(df,str_att_name,BM_MV):
    MV_labels = {True:'With Missing Values',False:'Without Missing Values'}

    labels=[]
    box_sr = pd.Series('',index = BM_MV.unique())
    for poss in BM_MV.unique():
        BM = BM_MV == poss
        box_sr[poss] = df[BM][str_att_name].dropna()
        labels.append(MV_labels[poss])

    plt.boxplot(box_sr,vert=False)
    plt.yticks([1,2],labels)
    plt.xlabel(str_att_name)
    plt.show()

    plt.figure(figsize=(10,4))

    att_range = (df[str_att_name].min(),df[str_att_name].max())

    for i,poss in enumerate(BM_MV.unique()):
        plt.subplot(1,2,i+1)
        BM = BM_MV == poss
        df[BM][str_att_name].hist()
        plt.xlim = att_range
        plt.xlabel(str_att_name)
        plt.title(MV_labels[poss])

    plt.show()

    group_1_data = df[BM_MV][str_att_name].dropna()
    group_2_data = df[~BM_MV][str_att_name].dropna()

    p_value = ttest_ind(group_1_data,group_2_data).pvalue

    print('p-value of t-test: {}'.format(p_value))

# %%
from scipy.stats import chi2_contingency
def Diagnose_MV_Categorical(df,str_att_name,BM_MV):
    MV_labels = {True:'With Missing Values',False:'Without Missing Values'}

    plt.figure(figsize=(10,4))
    for i,poss in enumerate(BM_MV.unique()):
        plt.subplot(1,2,i+1)
        BM = BM_MV == poss
        df[BM][str_att_name].value_counts().plot.bar()
        plt.title(MV_labels[poss])
    plt.show()

    contigency_table = pd.crosstab(BM_MV,df[str_att_name])
    p_value = chi2_contingency(contigency_table)[1]

    print('p-value of Chi_squared test: {}'.format(p_value))

# %%
#Relación de valores faltantes de 'Weight' con variables numéricas: 'Age' & 'Number of siblings'
#De acuerdo al resultado en las pruebas y a lo observado en la gráfica se deduce que:
#No hay relación significativa entre los valores faltantes de Weight con la variable 'Age' valor p-value de 72%.
#No hay relación significativa entre los valores faltantes de Weight con la variable 'Number of Siblings' valor de p-value es 82%.
numerical_attributes = ['Age', 'Number of siblings']

BM_MV = response_df.Weight.isna()

for att in numerical_attributes:

    print('Diagnosis Analysis of Missing Values for {}:'.    format(att))

    Diagnose_MV_Numerical(response_df,att,BM_MV)

    print('- - - - - - - - - - divider - - - - - - - - - ')
# Out:
# Diagnosis Analysis of Missing Values for Age:
# p-value of t-test: 0.7258243979822129
# - - - - - - - - - - divider - - - - - - - - -
# Diagnosis Analysis of Missing Values for Number of siblings:
# p-value of t-test: 0.8255092107556896
# - - - - - - - - - - divider - - - - - - - - -

# %%
#Relación de valores faltantes de 'Weight' con variables categóricas: 'Gender' & 'Education'
#De acuerdo al resultado en las pruebas y a lo observado en la gráfica se deduce que:
#No hay relación significativa entre los valores faltantes de Weight con la variable 'Gender' valor p-value de 54%.
#No hay relación significativa entre los valores faltantes de Weight con la variable 'Education' valor de p-value es 84%.

categorical_attributes = ['Gender', 'Education']

BM_MV = response_df.Weight.isna()
for att in categorical_attributes:
    print('Diagnosis Analysis of Missing Values for {}:'.format(att))
    Diagnose_MV_Categorical(response_df,att,BM_MV)
    print('- - - - - - - - - - - - divider - - - - - - - - - - - ')
# Out:
# Diagnosis Analysis of Missing Values for Gender:
# p-value of Chi_squared test: 0.5472167199163878
# - - - - - - - - - - - - divider - - - - - - - - - - -
# Diagnosis Analysis of Missing Values for Education:
# p-value of Chi_squared test: 0.8424822989541867
# - - - - - - - - - - - - divider - - - - - - - - - - -

# %% [markdown]
# 6. Utiliza una medida de tendencia central para imputar los valores faltantes de `Weight`. ¿Cuál es recomendable y por qué?

# %%
#La selección de la media o la mediana depende de la cantidad de outliers en la distribución de la variable "Weight" así como
#de la forma de la distribución, que en este caso por ser una distribución asimétrica no es fielmente representada por la media
#De acuerdo a lo anterior se selecciona la mediana para imputar los valores faltantes en el atributo "Weight"

response_df.Weight.fillna(response_df.Weight.median(),inplace=True)

# %% [markdown]
# 7. ¿Hay valores atípicos de la variable `Weight`? Confírmalo con un gráfico de boxplot. ¿Cuántos son? Almacénalos en un dataframe independiente y elimínalos del conjunto original.

# %%
#Se puede observar gran cantidad de outliers en el diagrama de box-plot
plt.boxplot(response_df.Weight.dropna(),vert=False)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x78458fedcd90>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x78458fedd330>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x78458feddb70>],
#  'medians': [<matplotlib.lines.Line2D at 0x78458fedff10>],
#  'fliers': [<matplotlib.lines.Line2D at 0x78458ffdcac0>],
#  'means': []}

# %%
#Usando el metodo IQR
#Se observa que la cantidad de Outliers es de 10
Q1 = response_df.Weight.quantile(0.25)
Q3 = response_df.Weight.quantile(0.75)
IQR = Q3-Q1
BM = (response_df.Weight > (Q3+1.5 *IQR)) | (response_df.Weight < (Q1-1.5 *IQR))

#Transmitiendo los valores a un dataframe de outliers
outliers_weight_df = response_df[BM]
#Borrando los outliers del dataframe original

response_df = response_df[~BM]

outliers_weight_df['Weight']
# Out:
# 292    120.0
# 612    110.0
# 715    111.0
# 793    120.0
# 796    113.0
# 859    125.0
# 885    165.0
# 973    120.0
# 992    150.0
# 998    105.0
# Name: Weight, dtype: float64

# %%
#Se comprueba que se han eliminado los 10 outliers del dataframe original
response_df.shape
# Out:
# (1000, 150)

# %% [markdown]
# 8. Repite el mismo proceso de valores atípicos con la variable `Height`.

# %%
#Se puede observar esta cantidad de outliers en el diagrama de box-plot
plt.boxplot(response_df.Height.dropna(),vert=False)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x784594d68400>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x784594d69630>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x784594d6a200>],
#  'medians': [<matplotlib.lines.Line2D at 0x784594d68a00>],
#  'fliers': [<matplotlib.lines.Line2D at 0x784594d69c90>],
#  'means': []}

# %%
#Usando el metodo IQR
#Se observa que la cantidad de Outliers es de: 5
Q1 = response_df.Height.quantile(0.25)
Q3 = response_df.Height.quantile(0.75)
IQR = Q3-Q1
BM = (response_df.Height > (Q3+1.5 *IQR)) | (response_df.Height < (Q1-1.5 *IQR))

#Transmitiendo los valores a un dataframe de outliers
outliers_height_df = response_df[BM]
#Borrando los outliers del dataframe original

response_df = response_df[~BM]

outliers_height_df['Height']
# Out:
# 97     200.0
# 220    200.0
# 547    203.0
# 676     62.0
# 799    203.0
# Name: Height, dtype: float64

# %%
#Se comprueba que se han eliminado los 5 outliers del dataframe original
response_df.shape
# Out:
# (995, 150)

# %% [markdown]
# 9. ¿Hay encuestados que sean atípicos según su índice de masa corporal (`BMI`)? El `BMI` puede ser calculado usando la siguiente fórmula:
#
# `BMI = Weight / Height ^ 2`
#
# **NOTA**. El peso tiene que estar en kilogramos y la altura en metros, pero en el conjunto la altura se ha registrado en centímetros, por lo que deberás convertirla a metros.

# %%
#Convirtiendo centimetros a metros
response_df['Height_cm'] = response_df['Height']/100
#Calculando el indice BMI
response_df['BMI'] = response_df['Weight'] / (response_df['Height_cm']**2)

#Usando el metodo IQR
#Se observa que la cantidad de Outliers para BMI es de: 6
Q1 = response_df.BMI.quantile(0.25)
Q3 = response_df.BMI.quantile(0.75)
IQR = Q3-Q1
BM = (response_df.BMI > (Q3+1.5 *IQR)) | (response_df.BMI < (Q1-1.5 *IQR))

response_df[BM].BMI
# Out:
# <ipython-input-162-b61f4d69701b>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   response_df['Height_cm'] = response_df['Height']/100
# <ipython-input-162-b61f4d69701b>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   response_df['BMI'] = response_df['Weight'] / (response_df['Height_cm']**2)
# 42     31.141869
# 151    30.864198
# 156    30.961729
# 357    29.961612
# 401    31.141869
# 636    31.804658
# Name: BMI, dtype: float64

# %%
plt.boxplot(response_df.BMI.dropna(),vert=False)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7845948fb550>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7845948f9120>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x78459578cf40>],
#  'medians': [<matplotlib.lines.Line2D at 0x784597d4c970>],
#  'fliers': [<matplotlib.lines.Line2D at 0x784597d4ceb0>],
#  'means': []}

# %% [markdown]
# 10. Utiliza boxplots para visualizar la distribución del `BMI` según cada una de las variables categóricas de texto. Comenta un hallazgo que llame tu atención.

# %%
variables_categoricas = response_df.describe(include = 'object').T.index
fig, axes = plt.subplots(4,3, figsize=(25,25))
plt.subplots_adjust(hspace=0.5)
axes = axes.ravel()
for col, ax in zip(variables_categoricas, axes):
    sns.boxplot(x=col, y = 'BMI', data = response_df, ax=ax)
    ax.set(title=f'{col}', xlabel=None)
    ax.tick_params(axis='x',rotation=25)

fig.subplots_adjust(wspace=.5, hspace=.5)

#El indice de masa corporal es por lo general mayor en los hombres.
#El indice de masa corporal es significativamente mas grande en las personas con grado de doctorado.
